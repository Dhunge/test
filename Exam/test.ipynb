# %% [markdown]
# # Nish Adhikari

# %% [markdown]
# ## University ID: c7682972

# %% [markdown]
# ### Hello how are you doing? I am using VS code and i am learning python right now and i am learning how to use markdown

# %%
# task1
# Function to find the number is odd or even.
int
